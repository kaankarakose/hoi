# %%
import os
import glob
import pandas as pd
from pathlib import Path
import argparse

class VideoManager:
    def __init__(self, base_dir="/nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb"):
        self.base_dir = Path(base_dir)
        print(f"Base directory: {base_dir}")

    def list_camera_views(self):
        """List all camera view directories (cam_side_l, cam_side_r, cam_top)"""
        return [d for d in self.base_dir.glob("cam_*") if d.is_dir()]
    
    def list_folders(self, camera_dir):
        """List all folders (calibration, imi, zolti) for a given camera view"""
        return [d for d in camera_dir.glob("*") if d.is_dir()]
    
    def list_persons(self, camera_dir):
        """List only person folders (imi, zolti) for a given camera view, excluding calibration"""
        return [d for d in camera_dir.glob("*") if d.is_dir() and d.name != "calibration"]
        
    def list_sessions(self, person_dir):
        """List all session directories for a given person"""
        return [d for d in person_dir.glob("session*") if d.is_dir()]
    
    def list_videos(self, session_dir):
        """List all video files in a session directory"""
        video_extensions = ["*.mp4", "*.avi", "*.mov"]
        videos = []
        for ext in video_extensions:
            videos.extend(session_dir.glob(ext))
        
        return sorted(videos) #
    
    def create_inventory(self):
        """Create a comprehensive inventory of all videos"""
        records = []
        
        for camera_dir in self.list_camera_views():
            camera_view = camera_dir.name
            
            for person_dir in self.list_persons(camera_dir):
                person = person_dir.name
                
                for session_dir in self.list_sessions(person_dir):
                    session = session_dir.name
                    
                    # Sort videos within this session directory
                    videos = sorted(self.list_videos(session_dir))
                    
                    # Assign index-based sync identifiers based on sort order
                    for index, video_file in enumerate(videos):
                        file_size_mb = video_file.stat().st_size / (1024 * 1024)
                        
                        records.append({
                            "camera_view": camera_view,
                            "person": person,
                            "session": session,
                            "filename": video_file.name,
                            "path": str(video_file),
                            "size_mb": round(file_size_mb, 2),
                            "position_index": index
                        })
            # Handle calibration folder separately if it exists
            calibration_dir = camera_dir / "calibration"
            if calibration_dir.exists() and calibration_dir.is_dir():
                # Sort calibration videos
                videos = sorted(self.list_videos(calibration_dir))
                
                for index, video_file in enumerate(videos):
                    file_size_mb = video_file.stat().st_size / (1024 * 1024)
                    
                    # Use a combination of 'calibration' and index as the sync group
                    sync_group = f"calibration_{index}"
                    
                    records.append({
                        "camera_view": camera_view,
                        "person": "calibration",
                        "session": "",  # No session for calibration
                        "filename": video_file.name,
                        "path": str(video_file),
                        "size_mb": round(file_size_mb, 2),
                        "position_index": index
                    })
        
        return pd.DataFrame(records)

# %%
base_dir= "/nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb"
inventory= True 
output = "video_inventory.csv",      
manager = VideoManager(base_dir)
# Out:
# Base directory: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb

# %%
df = manager.create_inventory()

# %%
df.columns
# Out:
# Index(['camera_view', 'person', 'session', 'filename', 'path', 'size_mb',
#        'position_index'],
#       dtype='object')

# %%
result = df.pivot(
    index=['person', 'session', 'position_index'],
    columns='camera_view',
    values=['filename', 'path', 'size_mb']
)

# %%
# Flatten the multi-level column names
result.columns = ['_'.join(col).strip() for col in result.columns.values]
result = result.reset_index()

# %%
result = pd.pivot_table(
    df,
    index=['person', 'session', 'position_index'],
    columns='camera_view',
    values=['filename', 'path', 'size_mb'],
    aggfunc={'path': 'first', 'size_mb': 'mean'}
)

# %%
result.to_csv('test.csv')

# %%
result.columns = ['_'.join(col).strip() for col in result.columns.values]

# %%
result = result.reset_index()

# %%
result.columns
# Out:
# Index(['person', 'session', 'position_index', 'path_cam_side_l',
#        'path_cam_side_r', 'path_cam_top', 'size_mb_cam_side_l',
#        'size_mb_cam_side_r', 'size_mb_cam_top'],
#       dtype='object')

# %%
import pandas as pd
import os
import shutil

def organize_videos_by_session(df, base_output_dir):
    """
    Organizes video files into folders based on person_session identifiers
    
    Parameters:
    df (DataFrame): DataFrame containing 'person_session' and path columns for different camera views
    base_output_dir (str): Base directory where folders will be created
    """
    # Make sure base output directory exists
    if not os.path.exists(base_output_dir):
        os.makedirs(base_output_dir)
    
    # Get all path columns (those containing 'path_')
    path_columns = [col for col in df.columns if 'path_' in col]
    
    # Create mapping for camera view names from column names
    # Example: 'path_cam_top' -> 'cam_top'
    camera_view_names = {col: col.replace('path_', '') for col in path_columns}
    
    # Process each row in the DataFrame
    for index, row in df.iterrows():
        # Get person_session value for this row
        session_id = row['person_session']
        
        # Create a directory for this session
        session_dir = os.path.join(base_output_dir, session_id)
        if not os.path.exists(session_dir):
            os.makedirs(session_dir)

        # Process each camera view for this session
        for path_col in path_columns:
            # Get the source path
            src_path = row[path_col]
            
            # Skip if path is missing
            if pd.isna(src_path) or not src_path:
                continue
                
            # Get camera view name for filename
            camera_view = camera_view_names[path_col]
            
            # Extract the original filename from the path
            original_filename = os.path.basename(src_path)
            
            # Create a destination path with camera view prefix
            dest_filename = f"{camera_view}_{original_filename}"
            dest_path = os.path.join(session_dir, dest_filename)
            
            # Copy the file (use shutil.move if you want to move instead of copy)
            try:
                print(f"Copying {src_path} to {dest_path}")
                shutil.copy2(src_path, dest_path)
            except Exception as e:
                print(f"Error processing {src_path}: {str(e)}")
    
    print(f"Video organization complete. Files organized in {base_output_dir}")

# %%
result
# Out:
#          person   session  position_index  \
# 0   calibration                         0
# 1   calibration                         1
# 2           imi  session1               0
# 3           imi  session1               1
# 4           imi  session1               2
# 5           imi  session1               3
# 6           imi  session1               4
# 7           imi  session1               5
# 8           imi  session1               6
# 9           imi  session1               7
# 10          imi  session2               0
# 11          imi  session2               1
# 12          imi  session2               2
# 13          imi  session2               3
# 14          imi  session2               4
# 15          imi  session2               5
# 16        zolti  session1               0
# 17        zolti  session1               1
# 18        zolti  session1               2
# 19        zolti  session1               3
# 20        zolti  session1               4
# 21        zolti  session2               0
# 22        zolti  session2               1
# 23        zolti  session2               2
# 24        zolti  session2               3
# 25        zolti  session2               4
#
#                                       path_cam_side_l  \
# 0   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 1   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 2   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 3   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 4   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 5   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 6   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 7   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 8   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 9   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 10  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 11  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 12  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 13  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 14  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 15  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 16  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 17  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 18  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 19  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 20  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 21  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 22  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 23  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 24  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 25  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
#
#                                       path_cam_side_r  \
# 0   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 1   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 2   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 3   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 4   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 5   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 6   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 7   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 8   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 9   /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 10  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 11  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 12  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 13  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 14  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 15  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 16  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 17  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 18  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 19  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 20  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 21  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 22  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 23  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 24  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
# 25  /nas/project_data/B1_Behavior/rush/mb_inhouse/...
#
#                                          path_cam_top  size_mb_cam_side_l  \
# 0   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              118.61
# 1   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              128.83
# 2   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.10
# 3   /nas/project_data/B1_Behavior/rush/mb_inhouse/...               75.09
# 4   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.19
# 5   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.20
# 6   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              134.06
# 7   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.99
# 8   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              131.80
# 9   /nas/project_data/B1_Behavior/rush/mb_inhouse/...              136.05
# 10  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              129.39
# 11  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.37
# 12  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.59
# 13  /nas/project_data/B1_Behavior/rush/mb_inhouse/...                1.73
# 14  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.37
# 15  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              133.81
# 16  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.72
# 17  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.99
# 18  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.04
# 19  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.14
# 20  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.64
# 21  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.68
# 22  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              132.43
# 23  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              129.90
# 24  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              138.84
# 25  /nas/project_data/B1_Behavior/rush/mb_inhouse/...              130.25
#
#     size_mb_cam_side_r  size_mb_cam_top
# 0               118.64           118.63
# 1               128.91           128.90
# 2               130.08           110.65
# 3                75.09            63.83
# 4               130.23           110.70
# 5               132.22           112.43
# 6               134.09           114.07
# 7               133.03           113.21
# 8               131.82           112.09
# 9               136.05           115.67
# 10              129.40           109.99
# 11              132.38           112.57
# 12              132.65           112.81
# 13                1.74             1.50
# 14              132.37           112.61
# 15              133.83           113.83
# 16              130.76           130.77
# 17              131.01           130.98
# 18              130.02           130.03
# 19              130.17           130.15
# 20              130.72           130.67
# 21              132.44           130.69
# 22              129.94           132.45
# 23              138.88           129.96
# 24              130.26           138.88
# 25               47.71           130.34

# %%
# Get all path columns (those containing 'path_')
path_columns = [col for col in result.columns if 'path_' in col]

# %%
camera_view_names = {col: col.replace('path_', '') for col in path_columns}

# %%
path_columns
# Out:
# ['path_cam_side_l', 'path_cam_side_r', 'path_cam_top']

# %%
result.columns
# Out:
# Index(['person', 'session', 'position_index', 'path_cam_side_l',
#        'path_cam_side_r', 'path_cam_top', 'size_mb_cam_side_l',
#        'size_mb_cam_side_r', 'size_mb_cam_top'],
#       dtype='object')

# %%
import shutil
output_path = '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data'
# Process each row in the DataFrame
index = 0 
for index, row in result.iterrows():
    if index < 19: continue
    # Get person_session value for this row
    session_id = row['person'] + '_' + row['session'] + '_' + str(index)
    # Create a directory for this session
    session_dir = os.path.join(output_path, session_id)
    if not os.path.exists(session_dir):
        os.makedirs(session_dir)
    
    # Process each camera view for this session
    for path_col in path_columns:
        src_path = row[path_col]

         # Get camera view name for filename
        camera_view = camera_view_names[path_col]
        
        # Extract the original filename from the path
        original_filename = os.path.basename(src_path)
        
        # Create a destination path with camera view prefix
        dest_filename = f"{camera_view}_{original_filename}"

        dest_path = os.path.join(session_dir, dest_filename)

        # Copy the file (use shutil.move if you want to move instead of copy)
        try:
            print(f"Copying {src_path} to {dest_path}")
            shutil.copy2(src_path, dest_path)
        except Exception as e:
            print(f"Error processing {src_path}: {str(e)}")
# Out:
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session1/Basler_a2A1920-160ucBAS__40399468__20250219_174949435.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174949435.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session1/Basler_a2A1920-160ucBAS__40399460__20250219_174948489.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174948489.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session1/Basler_a2A1920-160ucBAS__40401031__20250219_174950347.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174950347.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session1/Basler_a2A1920-160ucBAS__40399468__20250219_175132281.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175132281.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session1/Basler_a2A1920-160ucBAS__40399460__20250219_175131412.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175131412.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session1/Basler_a2A1920-160ucBAS__40401031__20250219_175133280.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175133280.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175346432.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175346432.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175518981.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175518981.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175347332.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175347332.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175519800.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175519800.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175744281.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175744281.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175520650.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175520650.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175745154.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175745154.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175745997.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175745997.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_180320568.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180320568.mp4
# Copying /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4 to /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4

# %%
import os
import subprocess

def extract_frames_subprocess(video_path, output_dir, frame_rate=None, quality=1):
    """
    Extract frames from a video using subprocess to run ffmpeg command.
    
    Args:
        video_path (str): Path to the video file
        output_dir (str): Directory to save extracted frames
        frame_rate (float, optional): Extract frames at this rate (fps)
                                     If None, extract all frames
        quality (int, optional): JPEG quality (1-31, lower is better quality)
                                Default is 1 for highest quality
    
    Returns:
        bool: True if extraction was successful, False otherwise
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Use the specific ffmpeg path
    ffmpeg_path = '/home/kaan/bin/ffmpeg'
    
    # Build the command as a list (safer than shell=True)
    output_pattern = os.path.join(output_dir, "frame_%04d.jpg")
    cmd = [ffmpeg_path, '-i', video_path]
    
    if frame_rate is not None:
        cmd.extend(['-r', str(frame_rate)])
    
    cmd.extend(['-q:v', str(quality), '-qmin', str(quality), '-qmax', str(quality)])
    cmd.append(output_pattern)
    cmd.append('-y')
    
    try:
        # Execute the command using subprocess with args as list
        result = subprocess.run(
            cmd,
            check=True,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )

        # Display standard output
        print("Standard Output:")
        print(result.stdout)
        
        # Display standard error
        print("Standard Error:")
        print(result.stderr)
        print(f"Command executed successfully")
        return True
    except subprocess.CalledProcessError as e:
        print(f"Error executing command")
        print(f"Error details: {e}")
        print(f"STDERR: {e.stderr}")
        return False

# %%
# !source ~/.bashrc

# %%
import shutil
output_path = '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data'
# Process each row in the DataFrame
index = 0 
for index, row in result.iterrows():
    # Get person_session value for this row
    if row['person'] == 'calibration': continue
    session_id = row['person'] + '_' + row['session'] + '_' +str(index)
    # Create a directory for this session
    session_dir = os.path.join(output_path, session_id)
    if not os.path.exists(session_dir):
        os.makedirs(session_dir)
    
    # Process each camera view for this session
    for path_col in path_columns:
        src_path = row[path_col]
        
         # Get camera view name for filename
        camera_view = camera_view_names[path_col]
        # Extract the original filename from the path
        original_filename = os.path.basename(src_path)
        # Create a destination path with camera view prefix
        dest_filename = f"{camera_view}_{original_filename}"

        video_path = os.path.join(session_dir, dest_filename)
        output_path = os.path.join(session_dir, camera_view)
        
        if not os.path.exists(output_path):
            os.makedirs(output_path)

        #print(os.path.exists(video_path))
        print(video_path)
        #print(extract_frames_subprocess(video_path, output_path))
# Out:
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_170320088.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_170316318.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_170326473.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_170702025.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_170658686.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_170709473.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_171009827.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_171007581.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_171012180.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_171301962.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_171258452.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_171304742.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_171457812.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_171452843.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_171500244.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_171704628.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_171656744.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_171707798.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_171858831.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_171855411.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_171904399.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_172041530.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_172044476.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_172038801.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_172403366.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_172359956.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_172406792.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_172548519.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_172541659.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_172556465.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_172733419.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_172727312.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_172737019.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_172911220.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_172907134.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_172913320.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_173114488.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_173102351.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_173116736.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_173305337.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_173301814.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_173307898.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174452544.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174451674.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174453363.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174632380.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174631639.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174633297.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174806746.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174805945.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174807660.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174949435.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174948489.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174950347.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175132281.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175131412.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175133280.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175346432.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175518981.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175347332.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175519800.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175744281.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175520650.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175745154.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175745997.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_top/zolti_session2_25/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_top/zolti_session2_25/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180320568.mp4
# /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/imi_session1_2/cam_top/imi_session1_3/cam_top/imi_session1_4/cam_top/imi_session1_5/cam_top/imi_session1_6/cam_top/imi_session1_7/cam_top/imi_session1_8/cam_top/imi_session1_9/cam_top/imi_session2_10/cam_top/imi_session2_11/cam_top/imi_session2_12/cam_top/imi_session2_13/cam_top/imi_session2_14/cam_top/imi_session2_15/cam_top/zolti_session1_16/cam_top/zolti_session1_17/cam_top/zolti_session1_18/cam_top/zolti_session1_19/cam_top/zolti_session1_20/cam_top/zolti_session2_21/cam_top/zolti_session2_22/cam_top/zolti_session2_23/cam_top/zolti_session2_24/cam_top/zolti_session2_25/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4

# %%
base_output_path = '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data'
# Process each row in the DataFrame
index = 0 
for index, row in result.iterrows():
    if index < 19: continue
    # Get person_session value for this row
    if row['person'] == 'calibration': continue
    session_id = row['person'] + '_' + row['session'] + '_' +str(index)
    # Create a directory for this session
    session_dir = os.path.join(base_output_path, session_id)
    if not os.path.exists(session_dir):
        os.makedirs(session_dir)
    
    # Process each camera view for this session
    for path_col in path_columns:
        src_path = row[path_col]
        
        # Get camera view name for filename
        camera_view = camera_view_names[path_col]
        # Extract the original filename from the path
        original_filename = os.path.basename(src_path)
        # Create a destination path with camera view prefix
        dest_filename = f"{camera_view}_{original_filename}"
        video_path = os.path.join(session_dir, dest_filename)
        frames_output_path = os.path.join(session_dir, camera_view)
        
        if not os.path.exists(frames_output_path):
            os.makedirs(frames_output_path)
        
        # Check if video file exists at the expected path
        if os.path.exists(video_path):
            print(f"File exists: {video_path}")
            print(extract_frames_subprocess(video_path, frames_output_path))
        else:
            print(f"File missing: {video_path}")
            print(f"Original source path: {src_path}")
# Out:
# File exists: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_174949435.mp4
# Command executed successfully
# True
# File exists: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_174948489.mp4
# Command executed successfully
# True
# File exists: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_19/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_174950347.mp4
# Command executed successfully
# True
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175132281.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session1/Basler_a2A1920-160ucBAS__40399468__20250219_175132281.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175131412.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session1/Basler_a2A1920-160ucBAS__40399460__20250219_175131412.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session1_20/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175133280.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session1/Basler_a2A1920-160ucBAS__40401031__20250219_175133280.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175346432.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175346432.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175518981.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175518981.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_21/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175347332.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175347332.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175519800.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175519800.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175744281.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175744281.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_22/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175520650.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175520650.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175745154.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175745154.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_23/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175745997.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175745997.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_l/zolti/session2/Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180320568.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_side_r/zolti/session2/Basler_a2A1920-160ucBAS__40399460__20250219_180320568.mp4
# File missing: /nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4
# Original source path: /nas/project_data/B1_Behavior/rush/mb_inhouse/mb_imi_zolti_/mb/cam_top/zolti/session2/Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4

# %%
base_output_path = '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data'
# Process each row in the DataFrame
index = 0 
for index, row in result.iterrows():
    # Get person_session value for this row
    if row['person'] == 'calibration': continue
    session_id = row['person'] + '_' + row['session'] + '_' +str(index)
    # Create a directory for this session
    session_dir = os.path.join(base_output_path, session_id)
    if not os.path.exists(session_dir):
        os.makedirs(session_dir)
    
    # Process each camera view for this session
    for path_col in path_columns:
        src_path = row[path_col]
        
        # Get camera view name for filename
        camera_view = camera_view_names[path_col]
        # Extract the original filename from the path
        original_filename = os.path.basename(src_path)
        # Create a destination path with camera view prefix
        dest_filename = f"{camera_view}_{original_filename}"
        video_path = os.path.join(session_dir, dest_filename)
        frames_output_path = os.path.join(session_dir, camera_view)
        
        if not os.path.exists(frames_output_path):
            os.makedirs(frames_output_path)
        print(session_id,len(os.listdir(frames_output_path)))
# Out:
# imi_session1_2 1893
# imi_session1_2 1893
# imi_session1_2 1893
# imi_session1_3 1092
# imi_session1_3 1092
# imi_session1_3 1092
# imi_session1_4 1895
# imi_session1_4 1895
# imi_session1_4 1895
# imi_session1_5 1923
# imi_session1_5 1923
# imi_session1_5 1923
# imi_session1_6 1951
# imi_session1_6 1951
# imi_session1_6 1951
# imi_session1_7 1934
# imi_session1_7 1934
# imi_session1_7 1934
# imi_session1_8 1918
# imi_session1_8 1918
# imi_session1_8 1918
# imi_session1_9 1980
# imi_session1_9 1980
# imi_session1_9 1980
# imi_session2_10 1883
# imi_session2_10 1883
# imi_session2_10 1883
# imi_session2_11 1926
# imi_session2_11 1926
# imi_session2_11 1926
# imi_session2_12 1930
# imi_session2_12 1930
# imi_session2_12 1930
# imi_session2_13 23
# imi_session2_13 23
# imi_session2_13 23
# imi_session2_14 1926
# imi_session2_14 1926
# imi_session2_14 1926
# imi_session2_15 1945
# imi_session2_15 1945
# imi_session2_15 1945
# zolti_session1_16 1902
# zolti_session1_16 1902
# zolti_session1_16 1902
# zolti_session1_17 1906
# zolti_session1_17 1906
# zolti_session1_17 1906
# zolti_session1_18 1892
# zolti_session1_18 1892
# zolti_session1_18 1892
# zolti_session1_19 1894
# zolti_session1_19 1894
# zolti_session1_19 1894
# zolti_session1_20 1901
# zolti_session1_20 1901
# zolti_session1_20 1901
# zolti_session2_21 1901
# zolti_session2_21 1901
# zolti_session2_21 1901
# zolti_session2_22 1927
# zolti_session2_22 1927
# zolti_session2_22 1927
# zolti_session2_23 1890
# zolti_session2_23 1890
# zolti_session2_23 1890
# zolti_session2_24 2020
# zolti_session2_24 2020
# zolti_session2_24 2020
# zolti_session2_25 1896
# zolti_session2_25 1896
# zolti_session2_25 1896

# %%
## FIXING SOME PROBLEMATIC CASE

# %%
base_output_path = '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data'

# %%
for session_name in os.listdir(base_output_path):
    index  = int(session_name.split('_')[-1])
    if index < 24: continue
    session_dir = os.path.join(base_output_path, session_name)
    for video_name in os.listdir(session_dir):
        if not video_name.endswith('.mp4'): continue
        video_path = os.path.join(session_dir, video_name)

        if 'top' in video_name:
            camera_view = '_'.join(video_name.split('_', 3)[0:2])
        else:
            camera_view = '_'.join(video_name.split('_', 3)[0:3])

        frame_output_path = os.path.join(session_dir,camera_view)

        if not os.path.exists(frame_output_path):
            os.makedirs(frame_output_path)
        extract_frames_subprocess(video_path, frame_output_path)
# Out:
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_175938455.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:07.33, start: 0.000000, bitrate: 17297 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17295 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7818f4015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_l/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   63 fps=0.0 q=1.0 size=N/A time=00:00:02.36 bitrate=N/A speed=4.73x
# frame=  156 fps=156 q=1.0 size=N/A time=00:00:05.46 bitrate=N/A speed=5.47x
# frame=  251 fps=167 q=1.0 size=N/A time=00:00:08.63 bitrate=N/A speed=5.75x
# frame=  345 fps=172 q=1.0 size=N/A time=00:00:11.76 bitrate=N/A speed=5.88x
# frame=  438 fps=175 q=1.0 size=N/A time=00:00:14.86 bitrate=N/A speed=5.95x
# frame=  529 fps=176 q=1.0 size=N/A time=00:00:17.90 bitrate=N/A speed=5.97x
# frame=  622 fps=178 q=1.0 size=N/A time=00:00:21.00 bitrate=N/A speed=   6x
# frame=  715 fps=179 q=1.0 size=N/A time=00:00:24.10 bitrate=N/A speed=6.02x
# frame=  806 fps=179 q=1.0 size=N/A time=00:00:27.13 bitrate=N/A speed=6.03x
# frame=  897 fps=179 q=1.0 size=N/A time=00:00:30.16 bitrate=N/A speed=6.03x
# frame=  989 fps=180 q=1.0 size=N/A time=00:00:33.23 bitrate=N/A speed=6.04x
# frame= 1080 fps=180 q=1.0 size=N/A time=00:00:36.26 bitrate=N/A speed=6.04x
# frame= 1172 fps=180 q=1.0 size=N/A time=00:00:39.33 bitrate=N/A speed=6.05x
# frame= 1263 fps=180 q=1.0 size=N/A time=00:00:42.36 bitrate=N/A speed=6.05x
# frame= 1354 fps=180 q=1.0 size=N/A time=00:00:45.40 bitrate=N/A speed=6.05x
# frame= 1445 fps=181 q=1.0 size=N/A time=00:00:48.43 bitrate=N/A speed=6.05x
# frame= 1537 fps=181 q=1.0 size=N/A time=00:00:51.50 bitrate=N/A speed=6.06x
# frame= 1629 fps=181 q=1.0 size=N/A time=00:00:54.56 bitrate=N/A speed=6.06x
# frame= 1720 fps=181 q=1.0 size=N/A time=00:00:57.60 bitrate=N/A speed=6.06x
# frame= 1810 fps=181 q=1.0 size=N/A time=00:01:00.60 bitrate=N/A speed=6.06x
# frame= 1902 fps=181 q=1.0 size=N/A time=00:01:03.66 bitrate=N/A speed=6.06x
# frame= 1992 fps=181 q=1.0 size=N/A time=00:01:06.66 bitrate=N/A speed=6.06x
# [out#0/image2 @ 0x33e87d80] video:654658KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 2020 fps=181 q=1.0 Lsize=N/A time=00:01:07.33 bitrate=N/A speed=6.04x
#
# Command executed successfully
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_175939237.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:07.33, start: 0.000000, bitrate: 17302 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17299 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x73baa8015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_top/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   56 fps=0.0 q=1.0 size=N/A time=00:00:02.13 bitrate=N/A speed=4.27x
# frame=  142 fps=142 q=1.0 size=N/A time=00:00:05.00 bitrate=N/A speed=   5x
# frame=  228 fps=152 q=1.0 size=N/A time=00:00:07.86 bitrate=N/A speed=5.24x
# frame=  314 fps=157 q=1.0 size=N/A time=00:00:10.73 bitrate=N/A speed=5.37x
# frame=  399 fps=160 q=1.0 size=N/A time=00:00:13.56 bitrate=N/A speed=5.43x
# frame=  484 fps=161 q=1.0 size=N/A time=00:00:16.40 bitrate=N/A speed=5.47x
# frame=  569 fps=163 q=1.0 size=N/A time=00:00:19.23 bitrate=N/A speed=5.49x
# frame=  654 fps=163 q=1.0 size=N/A time=00:00:22.06 bitrate=N/A speed=5.52x
# frame=  737 fps=164 q=1.0 size=N/A time=00:00:24.83 bitrate=N/A speed=5.52x
# frame=  822 fps=164 q=1.0 size=N/A time=00:00:27.66 bitrate=N/A speed=5.53x
# frame=  906 fps=165 q=1.0 size=N/A time=00:00:30.46 bitrate=N/A speed=5.54x
# frame=  990 fps=165 q=1.0 size=N/A time=00:00:33.26 bitrate=N/A speed=5.54x
# frame= 1075 fps=165 q=1.0 size=N/A time=00:00:36.10 bitrate=N/A speed=5.55x
# frame= 1158 fps=165 q=1.0 size=N/A time=00:00:38.86 bitrate=N/A speed=5.55x
# frame= 1243 fps=166 q=1.0 size=N/A time=00:00:41.70 bitrate=N/A speed=5.56x
# frame= 1327 fps=166 q=1.0 size=N/A time=00:00:44.50 bitrate=N/A speed=5.56x
# frame= 1410 fps=166 q=1.0 size=N/A time=00:00:47.26 bitrate=N/A speed=5.56x
# frame= 1495 fps=166 q=1.0 size=N/A time=00:00:50.10 bitrate=N/A speed=5.57x
# frame= 1578 fps=166 q=1.0 size=N/A time=00:00:52.86 bitrate=N/A speed=5.56x
# frame= 1659 fps=166 q=1.0 size=N/A time=00:00:55.56 bitrate=N/A speed=5.56x
# frame= 1742 fps=166 q=1.0 size=N/A time=00:00:58.33 bitrate=N/A speed=5.55x
# frame= 1826 fps=166 q=1.0 size=N/A time=00:01:01.13 bitrate=N/A speed=5.56x
# frame= 1911 fps=166 q=1.0 size=N/A time=00:01:03.96 bitrate=N/A speed=5.56x
# frame= 1995 fps=166 q=1.0 size=N/A time=00:01:06.76 bitrate=N/A speed=5.56x
# [out#0/image2 @ 0x1f15f4c0] video:745719KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 2020 fps=166 q=1.0 Lsize=N/A time=00:01:07.33 bitrate=N/A speed=5.54x
#
# Command executed successfully
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_175937582.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:07.33, start: 0.000000, bitrate: 17301 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17299 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7616c8015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_24/cam_side_r/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   58 fps=0.0 q=1.0 size=N/A time=00:00:02.20 bitrate=N/A speed= 4.4x
# frame=  146 fps=146 q=1.0 size=N/A time=00:00:05.13 bitrate=N/A speed=5.13x
# frame=  235 fps=157 q=1.0 size=N/A time=00:00:08.10 bitrate=N/A speed= 5.4x
# frame=  322 fps=161 q=1.0 size=N/A time=00:00:11.00 bitrate=N/A speed= 5.5x
# frame=  409 fps=164 q=1.0 size=N/A time=00:00:13.90 bitrate=N/A speed=5.56x
# frame=  494 fps=165 q=1.0 size=N/A time=00:00:16.73 bitrate=N/A speed=5.58x
# frame=  578 fps=165 q=1.0 size=N/A time=00:00:19.53 bitrate=N/A speed=5.58x
# frame=  665 fps=166 q=1.0 size=N/A time=00:00:22.43 bitrate=N/A speed=5.61x
# frame=  751 fps=167 q=1.0 size=N/A time=00:00:25.30 bitrate=N/A speed=5.62x
# frame=  837 fps=167 q=1.0 size=N/A time=00:00:28.16 bitrate=N/A speed=5.63x
# frame=  920 fps=167 q=1.0 size=N/A time=00:00:30.93 bitrate=N/A speed=5.62x
# frame= 1006 fps=168 q=1.0 size=N/A time=00:00:33.80 bitrate=N/A speed=5.63x
# frame= 1091 fps=168 q=1.0 size=N/A time=00:00:36.63 bitrate=N/A speed=5.63x
# frame= 1175 fps=168 q=1.0 size=N/A time=00:00:39.43 bitrate=N/A speed=5.63x
# frame= 1260 fps=168 q=1.0 size=N/A time=00:00:42.26 bitrate=N/A speed=5.63x
# frame= 1344 fps=168 q=1.0 size=N/A time=00:00:45.06 bitrate=N/A speed=5.63x
# frame= 1429 fps=168 q=1.0 size=N/A time=00:00:47.90 bitrate=N/A speed=5.63x
# frame= 1513 fps=168 q=1.0 size=N/A time=00:00:50.70 bitrate=N/A speed=5.63x
# frame= 1598 fps=168 q=1.0 size=N/A time=00:00:53.53 bitrate=N/A speed=5.63x
# frame= 1683 fps=168 q=1.0 size=N/A time=00:00:56.36 bitrate=N/A speed=5.63x
# frame= 1767 fps=168 q=1.0 size=N/A time=00:00:59.16 bitrate=N/A speed=5.63x
# frame= 1852 fps=168 q=1.0 size=N/A time=00:01:02.00 bitrate=N/A speed=5.63x
# frame= 1936 fps=168 q=1.0 size=N/A time=00:01:04.80 bitrate=N/A speed=5.63x
# [out#0/image2 @ 0x2696b940] video:735432KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 2020 fps=169 q=1.0 Lsize=N/A time=00:01:07.33 bitrate=N/A speed=5.62x
#
# Command executed successfully
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_l_Basler_a2A1920-160ucBAS__40399468__20250219_180129889.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:03.20, start: 0.000000, bitrate: 17288 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17286 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fa428015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_l/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   64 fps=0.0 q=1.0 size=N/A time=00:00:02.40 bitrate=N/A speed= 4.8x
# frame=  165 fps=165 q=1.0 size=N/A time=00:00:05.76 bitrate=N/A speed=5.77x
# frame=  264 fps=176 q=1.0 size=N/A time=00:00:09.06 bitrate=N/A speed=6.04x
# frame=  362 fps=181 q=1.0 size=N/A time=00:00:12.33 bitrate=N/A speed=6.17x
# frame=  461 fps=184 q=1.0 size=N/A time=00:00:15.63 bitrate=N/A speed=6.25x
# frame=  556 fps=185 q=1.0 size=N/A time=00:00:18.80 bitrate=N/A speed=6.27x
# frame=  653 fps=187 q=1.0 size=N/A time=00:00:22.03 bitrate=N/A speed=6.29x
# frame=  749 fps=187 q=1.0 size=N/A time=00:00:25.23 bitrate=N/A speed=6.31x
# frame=  847 fps=188 q=1.0 size=N/A time=00:00:28.50 bitrate=N/A speed=6.33x
# frame=  943 fps=189 q=1.0 size=N/A time=00:00:31.70 bitrate=N/A speed=6.34x
# frame= 1040 fps=189 q=1.0 size=N/A time=00:00:34.93 bitrate=N/A speed=6.35x
# frame= 1135 fps=189 q=1.0 size=N/A time=00:00:38.10 bitrate=N/A speed=6.35x
# frame= 1231 fps=189 q=1.0 size=N/A time=00:00:41.30 bitrate=N/A speed=6.35x
# frame= 1327 fps=190 q=1.0 size=N/A time=00:00:44.50 bitrate=N/A speed=6.36x
# frame= 1424 fps=190 q=1.0 size=N/A time=00:00:47.73 bitrate=N/A speed=6.36x
# frame= 1517 fps=190 q=1.0 size=N/A time=00:00:50.83 bitrate=N/A speed=6.35x
# frame= 1612 fps=190 q=1.0 size=N/A time=00:00:54.00 bitrate=N/A speed=6.35x
# frame= 1709 fps=190 q=1.0 size=N/A time=00:00:57.23 bitrate=N/A speed=6.36x
# frame= 1804 fps=190 q=1.0 size=N/A time=00:01:00.40 bitrate=N/A speed=6.36x
# [out#0/image2 @ 0x16227e40] video:622010KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 1896 fps=190 q=1.0 Lsize=N/A time=00:01:03.20 bitrate=N/A speed=6.34x
#
# Command executed successfully
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_top_Basler_a2A1920-160ucBAS__40401031__20250219_180131119.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:03.20, start: 0.000000, bitrate: 17300 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17298 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x76d798015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_top/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   58 fps=0.0 q=1.0 size=N/A time=00:00:02.20 bitrate=N/A speed= 4.4x
# frame=  151 fps=151 q=1.0 size=N/A time=00:00:05.30 bitrate=N/A speed= 5.3x
# frame=  244 fps=163 q=1.0 size=N/A time=00:00:08.40 bitrate=N/A speed= 5.6x
# frame=  335 fps=167 q=1.0 size=N/A time=00:00:11.43 bitrate=N/A speed=5.72x
# frame=  426 fps=170 q=1.0 size=N/A time=00:00:14.46 bitrate=N/A speed=5.79x
# frame=  517 fps=172 q=1.0 size=N/A time=00:00:17.50 bitrate=N/A speed=5.83x
# frame=  608 fps=174 q=1.0 size=N/A time=00:00:20.53 bitrate=N/A speed=5.87x
# frame=  698 fps=174 q=1.0 size=N/A time=00:00:23.53 bitrate=N/A speed=5.88x
# frame=  787 fps=175 q=1.0 size=N/A time=00:00:26.50 bitrate=N/A speed=5.89x
# frame=  878 fps=176 q=1.0 size=N/A time=00:00:29.53 bitrate=N/A speed=5.91x
# frame=  967 fps=176 q=1.0 size=N/A time=00:00:32.50 bitrate=N/A speed=5.91x
# frame= 1055 fps=176 q=1.0 size=N/A time=00:00:35.43 bitrate=N/A speed= 5.9x
# frame= 1143 fps=176 q=1.0 size=N/A time=00:00:38.36 bitrate=N/A speed= 5.9x
# frame= 1233 fps=176 q=1.0 size=N/A time=00:00:41.36 bitrate=N/A speed=5.91x
# frame= 1320 fps=176 q=1.0 size=N/A time=00:00:44.26 bitrate=N/A speed= 5.9x
# frame= 1409 fps=176 q=1.0 size=N/A time=00:00:47.23 bitrate=N/A speed= 5.9x
# frame= 1498 fps=176 q=1.0 size=N/A time=00:00:50.20 bitrate=N/A speed= 5.9x
# frame= 1587 fps=176 q=1.0 size=N/A time=00:00:53.16 bitrate=N/A speed=5.91x
# frame= 1675 fps=176 q=1.0 size=N/A time=00:00:56.10 bitrate=N/A speed= 5.9x
# frame= 1764 fps=176 q=1.0 size=N/A time=00:00:59.06 bitrate=N/A speed=5.91x
# frame= 1853 fps=176 q=1.0 size=N/A time=00:01:02.03 bitrate=N/A speed=5.91x
# [out#0/image2 @ 0x297d50c0] video:699824KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 1896 fps=177 q=1.0 Lsize=N/A time=00:01:03.20 bitrate=N/A speed=5.89x
#
# Command executed successfully
# Standard Output:
#
# Standard Error:
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_r_Basler_a2A1920-160ucBAS__40399460__20250219_180128931.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf56.1.0
#   Duration: 00:01:03.20, start: 0.000000, bitrate: 17290 kb/s
#   Stream #0:0[0x1](und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1200 [SAR 1:1 DAR 8:5], 17288 kb/s, 30 fps, 30 tbr, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x72a19c015040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '/nas/project_data/B1_Behavior/rush/mb_inhouse/postprocess/nipg_hoi_data/zolti_session2_25/cam_side_r/frame_%04d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1200 [SAR 1:1 DAR 8:5], q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 mjpeg
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   61 fps=0.0 q=1.0 size=N/A time=00:00:02.30 bitrate=N/A speed= 4.6x
# frame=  155 fps=155 q=1.0 size=N/A time=00:00:05.43 bitrate=N/A speed=5.43x
# frame=  247 fps=165 q=1.0 size=N/A time=00:00:08.50 bitrate=N/A speed=5.66x
# frame=  338 fps=169 q=1.0 size=N/A time=00:00:11.53 bitrate=N/A speed=5.76x
# frame=  428 fps=171 q=1.0 size=N/A time=00:00:14.53 bitrate=N/A speed=5.81x
# frame=  518 fps=173 q=1.0 size=N/A time=00:00:17.53 bitrate=N/A speed=5.84x
# frame=  606 fps=173 q=1.0 size=N/A time=00:00:20.46 bitrate=N/A speed=5.85x
# frame=  695 fps=174 q=1.0 size=N/A time=00:00:23.43 bitrate=N/A speed=5.86x
# frame=  785 fps=174 q=1.0 size=N/A time=00:00:26.43 bitrate=N/A speed=5.87x
# frame=  874 fps=175 q=1.0 size=N/A time=00:00:29.40 bitrate=N/A speed=5.88x
# frame=  963 fps=175 q=1.0 size=N/A time=00:00:32.36 bitrate=N/A speed=5.88x
# frame= 1051 fps=175 q=1.0 size=N/A time=00:00:35.30 bitrate=N/A speed=5.88x
# frame= 1139 fps=175 q=1.0 size=N/A time=00:00:38.20 bitrate=N/A speed=5.88x
# frame= 1226 fps=175 q=1.0 size=N/A time=00:00:41.13 bitrate=N/A speed=5.87x
# frame= 1315 fps=175 q=1.0 size=N/A time=00:00:44.10 bitrate=N/A speed=5.88x
# frame= 1403 fps=175 q=1.0 size=N/A time=00:00:47.03 bitrate=N/A speed=5.88x
# frame= 1493 fps=176 q=1.0 size=N/A time=00:00:50.03 bitrate=N/A speed=5.88x
# frame= 1581 fps=176 q=1.0 size=N/A time=00:00:52.96 bitrate=N/A speed=5.88x
# frame= 1670 fps=176 q=1.0 size=N/A time=00:00:55.93 bitrate=N/A speed=5.89x
# frame= 1759 fps=176 q=1.0 size=N/A time=00:00:58.90 bitrate=N/A speed=5.89x
# frame= 1849 fps=176 q=1.0 size=N/A time=00:01:01.90 bitrate=N/A speed=5.89x
# [out#0/image2 @ 0x43d8ff80] video:695635KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame= 1896 fps=176 q=1.0 Lsize=N/A time=00:01:03.20 bitrate=N/A speed=5.88x
#
# Command executed successfully
